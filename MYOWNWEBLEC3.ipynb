# %%
# !pip install streamlit appdirs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 72.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 115.7 MB/s eta 0:00:00
# ...

# %%
# %%writefile streamlit_app.py
import streamlit as st
import appdirs as ad
ad.user_cache_dir = lambda *args: "/tmp"
from PIL import Image

st.title("Welcome to Cash & Carry Shop")
st.write('The Largest Retailing Store')
st.image("https://lh3.googleusercontent.com/gps-cs-s/AG0ilSzjEg8wbBdzTpriNlgUfw4kpdttyriRmSEYNthxpdvA4F-wLb0CAHix10mv5XVDYgSnKNXiI8yGWrLjNA8gk3ASLThfFfBE2VzaGwVtYk3dTk9eyr54ddLYMMZWysUO3NwrHpJGmQ=s680-w680-h510-rw", caption="All in One")

st.header("SHOP INSIDE PICTURE")
uploaded_file = st.file_uploader("https://lh3.googleusercontent.com/gps-cs-s/AG0ilSzjEg8wbBdzTpriNlgUfw4kpdttyriRmSEYNthxpdvA4F-wLb0CAHix10mv5XVDYgSnKNXiI8yGWrLjNA8gk3ASLThfFfBE2VzaGwVtYk3dTk9eyr54ddLYMMZWysUO3NwrHpJGmQ=s680-w680-h510-rw", type=["jpg", "png", "jpeg"])

if uploaded_file is not None:
    image = Image.open(uploaded_file)
    st.image(image, caption="Uploaded Image", use_column_width=True)
# Out:
# Overwriting streamlit_app.py

# %%
#create local tunnel
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦
# changed 22 packages in 831ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.42.29.90

# %%
# !streamlit run streamlit_app.py & >./logs.txt & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.42.29.90:8501
